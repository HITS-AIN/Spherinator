# %%
import pandas as pd

df = pd.read_parquet('/hits/fast/its/doserbd/data/machine-learning/SKIRT_synthetic_images_parquet/1.parquet')
df
# Out:
#     simulation snapshot subhalo_id  \
# 0       TNG100      099     118715
# 1       TNG100      099     118716
# 2       TNG100      099     118720
# 3       TNG100      099     118724
# 4       TNG100      099     118725
# ..         ...      ...        ...
# 123     TNG100      099     134855
# 124     TNG100      099     134856
# 125     TNG100      099     134857
# 126     TNG100      099     134858
# 127     TNG100      099     134859
#
#                                                   data
# 0    b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 1    b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 2    b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 3    b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 4    b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# ..                                                 ...
# 123  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 124  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# ...

# %%
from PIL import Image
from io import BytesIO

image = Image.open(BytesIO(df['data'][2]))
print(image.size)
image
# Out:
# (363, 363)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=363x363>
