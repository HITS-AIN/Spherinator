# %%
import torchvision.models as models
from torchsummary import summary

model = models.resnet18().cuda()
print(summary(model, input_size=(3, 91, 91), ))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 46, 46]           9,408
#        BatchNorm2d-2           [-1, 64, 46, 46]             128
#               ReLU-3           [-1, 64, 46, 46]               0
#          MaxPool2d-4           [-1, 64, 23, 23]               0
#             Conv2d-5           [-1, 64, 23, 23]          36,864
#        BatchNorm2d-6           [-1, 64, 23, 23]             128
#               ReLU-7           [-1, 64, 23, 23]               0
#             Conv2d-8           [-1, 64, 23, 23]          36,864
#        BatchNorm2d-9           [-1, 64, 23, 23]             128
#              ReLU-10           [-1, 64, 23, 23]               0
#        BasicBlock-11           [-1, 64, 23, 23]               0
#            Conv2d-12           [-1, 64, 23, 23]          36,864
#       BatchNorm2d-13           [-1, 64, 23, 23]             128
# ...
