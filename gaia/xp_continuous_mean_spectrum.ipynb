# %%
import pandas as pd

file = "/local_data/doserbd/data/gaia/xp_continuous_mean_spectrum/XpContinuousMeanSpectrum_000000-003111.csv"
gaia_data = pd.read_csv(file, comment='#')
gaia_data
# Out:
#                source_id          solution_id  bp_basis_function_id  \
# 0             4295806720  4545469030156206081                    56
# 1            38655544960  4545469030156206081                    56
# 2          1275606125952  4545469030156206081                    56
# 3          1653563247744  4545469030156206081                    56
# 4          2851858288640  4545469030156206080                    56
# ...                  ...                  ...                   ...
# 87085  27369696273745536  4545469030156206080                    56
# 87086  27370525202939904  4545469030156206081                    56
# 87087  27370662641891456  4545469030156206081                    56
# 87088  27370800080844416  4545469030156206081                    56
# 87089  27371109318489216  4545469030156206081                    56
#
#        bp_degrees_of_freedom  bp_n_parameters  bp_n_measurements  \
# 0                        931               55                986
# ...

# %%
gaia_data.iloc[0]
# Out:
# source_id                                                             4295806720
# solution_id                                                  4545469030156206081
# bp_basis_function_id                                                          56
# bp_degrees_of_freedom                                                        931
# bp_n_parameters                                                               55
# bp_n_measurements                                                            986
# bp_n_rejected_measurements                                                    10
# bp_standard_deviation                                                    0.99342
# bp_chi_squared                                                         918.78815
# bp_coefficients                [102.93398893929992,-12.336921213781045,-2.668...
# bp_coefficient_errors          [0.55094093,0.48301947,0.49546295,0.5173322,0....
# bp_coefficient_correlations    [0.11844608,-0.14125401,0.10548916,-0.04995000...
# ...

# %%
from gaiaxpy import convert

converted_data, sampling = convert(mean_spectrum_file, save_file=False)
# Out:
#                                                                          9<00:00, 618.05spec/s]

# %%
converted_data
# Out:
#                 source_id  xp  \
# 0              4295806720  BP
# 1              4295806720  RP
# 2             38655544960  BP
# 3             38655544960  RP
# 4           1275606125952  BP
# ...                   ...  ..
# 174175  27370662641891456  RP
# 174176  27370800080844416  BP
# 174177  27370800080844416  RP
# 174178  27371109318489216  BP
# 174179  27371109318489216  RP
#
#                                                      flux  \
# 0       [-0.13553347980860084, -0.10885359815487317, -...
# 1       [-0.4765170826566046, -0.4833122892161356, -0....
# 2       [17.228591178344455, 18.08151743905616, 18.896...
# 3       [8.551606718983232, 9.055884163349473, 9.56332...
# 4       [3.969872217256678, 4.135814948339407, 4.28916...
# ...                                                   ...
# 174175  [0.6044057563910972, 0.6136380809448103, 0.619...
# 174176  [2968.8487209909313, 3091.183162955987, 3203.6...
# 174177  [1280.9644778871366, 1409.2051519354486, 1545....
# ...

# %%
from gaiaxpy import plot_spectra

plot_spectra(converted_data[0:10], sampling=sampling, multi=False, show_plot=True)
