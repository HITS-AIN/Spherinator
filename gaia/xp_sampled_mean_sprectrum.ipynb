# %%
import pandas as pd

file = "/local_data/doserbd/data/gaia/xp_sampled_mean_spectrum/XpSampledMeanSpectrum_000000-003111.csv"
gaia_data = pd.read_csv(file, comment='#')
gaia_data
# Out:
#                source_id          solution_id         ra        dec  \
# 0            38655544960  4545469030156206081  45.004978   0.019880
# 1          2851858288640  4545469030156206080  45.132144   0.137854
# 2          3332894779520  4545469030156206081  45.058168   0.127402
# 3          3371550165888  4545469030156206080  45.033605   0.128549
# 4          4711579935744  4545469030156206081  44.894800   0.114031
# ...                  ...                  ...        ...        ...
# 23224  27369013374445184  4545469030156206080  44.734834  11.023099
# 23225  27369666209479424  4545469030156206080  44.596363  10.936273
# 23226  27369696273745536  4545469030156206080  44.605042  10.957271
# 23227  27370800080844416  4545469030156206081  44.563964  10.981979
# 23228  27371109318489216  4545469030156206081  44.555132  11.006496
#
#                                                     flux  \
# 0      [2.7225272E-17,1.8763725E-17,1.4287515E-17,1.4...
# ...

# %%
import numpy as np

spectrum = np.fromstring(gaia_data['flux'][0][1:-1], sep=',')
spectrum.shape
# Out:
# (343,)

# %%
import matplotlib.pyplot as plt

plt.plot(range(spectrum.shape[0]), spectrum)
plt.show()
