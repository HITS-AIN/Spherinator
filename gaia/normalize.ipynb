# %%
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
import numpy as np
from gaiaxpy import convert

mean_spectrum_file = "/local_data/doserbd/data/gaia/XpContinuousMeanSpectrum_000000-003111.csv"

sampling = np.linspace(0.0, 60.0, 600)
converted_data, sampling = convert(mean_spectrum_file, sampling=sampling, save_file=False)
# Out:
#                                                                           <00:00, 1954.03spec/s]

# %%
sum = converted_data['flux'].apply(lambda x: x.sum())
converted_data['flux'] /= sum
converted_data['flux_error'] /= sum

# %%
from gaiaxpy import plot_spectra

plot_spectra(converted_data[0:10], sampling=sampling, multi=False, show_plot=True)
